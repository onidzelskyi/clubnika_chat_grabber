# %%
# -*- coding: utf-8 -*-
import sqlite3

conn = sqlite3.connect("clubnika.db")
cur = conn.cursor()
msg = conn.execute("select msg from messages where length(phone)>10 order by length(phone) desc").fetchall()

# %%
import re
operators = [u"039", u"050", u"063", u"066", u"067", u"068", u"091", u"092", u"093", u"094", u"095", u"096", u"097", u"098", u"099"]
for entry in msg:
    parts = re.sub("[^0-9]", " ", entry[0]).split()
    print parts,
    for i, part in enumerate(parts):
        founded = False
        for operator in operators:
            if len(re.findall(operator, part)): 
                print operator, part
                founded = True
                break
        if founded: break
        else: del parts[i]

    print parts
# Out:
# [u'35', u'0666532882', u'0666532882'] 066 0666532882
# [u'0666532882', u'0666532882']
# [u'35', u'0666532882', u'0666532882'] 066 0666532882
# [u'0666532882', u'0666532882']
# [u'0930566281', u'0930566281'] 093 0930566281
# [u'0930566281', u'0930566281']
# [u'0930566281', u'0930566281'] 093 0930566281
# [u'0930566281', u'0930566281']
# [u'0930566281', u'0930566281'] 093 0930566281
# [u'0930566281', u'0930566281']
# [u'0930566281', u'0930566281'] 093 0930566281
# [u'0930566281', u'0930566281']
# [u'35', u'0666532882', u'0666532882'] 066 0666532882
# [u'0666532882', u'0666532882']
# [u'35', u'0666532882', u'0666532882'] 066 0666532882
# [u'0666532882', u'0666532882']
# [u'0930566281', u'0930566281'] 093 0930566281
# [u'0930566281', u'0930566281']
# [u'0930566281', u'0930566281'] 093 0930566281
# [u'0930566281', u'0930566281']
# [u'35', u'0666532882', u'0666532882'] 066 0666532882
# [u'0666532882', u'0666532882']
# [u'35', u'0666532882', u'0666532882'] 066 0666532882
# ...

# %%
help(re.findall)
# Out:
# Help on function findall in module re:
#
# findall(pattern, string, flags=0)
#     Return a list of all non-overlapping matches in the string.
#
#     If one or more groups are present in the pattern, return a
#     list of groups; this will be a list of tuples if the pattern
#     has more than one group.
#
#     Empty matches are included in the result.

# %%
re.findall(u"068", u"0688734289")
# Out:
# [u'068']
